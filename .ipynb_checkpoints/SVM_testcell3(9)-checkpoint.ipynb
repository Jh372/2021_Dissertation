# %%
# import library
from glob import glob
import os
from os.path import join
# import random
from sklearn import svm
from sklearn import datasets
import joblib
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import openpyxl

# %%
def split_ratio(train_ratio, img_src):
    # get file list
    files = glob(join(img_src, '*.csv'))
    # split data into train and test sets(8:2)
    train_file, test_file = train_test_split(files, train_size=train_ratio)
    return train_file, test_file

# def train_SVM(filename, src):

# %%
train_file, test_file = split_ratio(0.8,'./step2/output7_csv')
df1 = pd.DataFrame(train_file)
df2 = pd.DataFrame(test_file)
df1.to_csv('./train_file7_list.csv', index=None)
df2.to_csv('./test_file7_list.csv', index=None)

# %%
train_file = np.loadtxt('./train_file_list.csv', delimiter=',',skiprows=1, dtype='object')
train_file
# Out:
# array([['0', './step2/output_csv/data192.csv'],
#        ['1', './step2/output_csv/data117.csv'],
#        ['2', './step2/output_csv/data196.csv'],
#        ['3', './step2/output_csv/data172.csv'],
#        ['4', './step2/output_csv/data155.csv'],
#        ['5', './step2/output_csv/data64.csv'],
#        ['6', './step2/output_csv/data111.csv'],
#        ['7', './step2/output_csv/data156.csv'],
#        ['8', './step2/output_csv/data95.csv'],
#        ['9', './step2/output_csv/data176.csv'],
#        ['10', './step2/output_csv/data159.csv'],
#        ['11', './step2/output_csv/data200.csv'],
#        ['12', './step2/output_csv/data45.csv'],
#        ['13', './step2/output_csv/data157.csv'],
#        ['14', './step2/output_csv/data151.csv'],
#        ['15', './step2/output_csv/data83.csv'],
#        ['16', './step2/output_csv/data7.csv'],
#        ['17', './step2/output_csv/data147.csv'],
#        ['18', './step2/output_csv/data1.csv'],
#        ['19', './step2/output_csv/data140.csv'],
#        ['20', './step2/output_csv/data49.csv'],
#        ['21', './step2/output_csv/data78.csv'],
#        ['22', './step2/output_csv/data5.csv'],
#        ['23', './step2/output_csv/data189.csv'],
#        ['24', './step2/output_csv/data173.csv'],
#        ['25', './step2/output_csv/data72.csv'],
#        ['26', './step2/output_csv/data191.csv'],
#        ['27', './step2/output_csv/data80.csv'],
#        ['28', './step2/output_csv/data171.csv'],
#        ['29', './step2/output_csv/data96.csv'],
#        ['30', './step2/output_csv/data174.csv'],
#        ['31', './step2/output_csv/data127.csv'],
#        ['32', './step2/output_csv/data20.csv'],
#        ['33', './step2/output_csv/data8.csv'],
#        ['34', './step2/output_csv/data74.csv'],
#        ['35', './step2/output_csv/data84.csv'],
#        ['36', './step2/output_csv/data195.csv'],
#        ['37', './step2/output_csv/data66.csv'],
#        ['38', './step2/output_csv/data87.csv'],
#        ['39', './step2/output_csv/data128.csv'],
#        ['40', './step2/output_csv/data106.csv'],
#        ['41', './step2/output_csv/data153.csv'],
#        ['42', './step2/output_csv/data4.csv'],
#        ['43', './step2/output_csv/data88.csv'],
#        ['44', './step2/output_csv/data101.csv'],
#        ['45', './step2/output_csv/data112.csv'],
#        ['46', './step2/output_csv/data178.csv'],
#        ['47', './step2/output_csv/data109.csv'],
#        ['48', './step2/output_csv/data33.csv'],
#        ['49', './step2/output_csv/data148.csv'],
#        ['50', './step2/output_csv/data27.csv'],
#        ['51', './step2/output_csv/data90.csv'],
#        ['52', './step2/output_csv/data102.csv'],
#        ['53', './step2/output_csv/data145.csv'],
#        ['54', './step2/output_csv/data9.csv'],
#        ['55', './step2/output_csv/data77.csv'],
#        ['56', './step2/output_csv/data185.csv'],
#        ['57', './step2/output_csv/data105.csv'],
#        ['58', './step2/output_csv/data28.csv'],
#        ['59', './step2/output_csv/data11.csv'],
#        ['60', './step2/output_csv/data144.csv'],
#        ['61', './step2/output_csv/data152.csv'],
#        ['62', './step2/output_csv/data160.csv'],
#        ['63', './step2/output_csv/data169.csv'],
#        ['64', './step2/output_csv/data32.csv'],
#        ['65', './step2/output_csv/data104.csv'],
#        ['66', './step2/output_csv/data94.csv'],
#        ['67', './step2/output_csv/data154.csv'],
#        ['68', './step2/output_csv/data108.csv'],
#        ['69', './step2/output_csv/data131.csv'],
#        ['70', './step2/output_csv/data138.csv'],
#        ['71', './step2/output_csv/data110.csv'],
#        ['72', './step2/output_csv/data158.csv'],
#        ['73', './step2/output_csv/data162.csv'],
#        ['74', './step2/output_csv/data150.csv'],
#        ['75', './step2/output_csv/data183.csv'],
#        ['76', './step2/output_csv/data149.csv'],
#        ['77', './step2/output_csv/data107.csv'],
#        ['78', './step2/output_csv/data89.csv'],
#        ['79', './step2/output_csv/data55.csv'],
#        ['80', './step2/output_csv/data14.csv'],
#        ['81', './step2/output_csv/data93.csv'],
#        ['82', './step2/output_csv/data139.csv'],
#        ['83', './step2/output_csv/data85.csv'],
#        ['84', './step2/output_csv/data53.csv'],
#        ['85', './step2/output_csv/data119.csv'],
#        ['86', './step2/output_csv/data118.csv'],
#        ['87', './step2/output_csv/data143.csv'],
#        ['88', './step2/output_csv/data199.csv'],
#        ['89', './step2/output_csv/data175.csv'],
#        ['90', './step2/output_csv/data170.csv'],
#        ['91', './step2/output_csv/data167.csv'],
#        ['92', './step2/output_csv/data82.csv'],
#        ['93', './step2/output_csv/data115.csv'],
#        ['94', './step2/output_csv/data62.csv'],
#        ['95', './step2/output_csv/data132.csv'],
#        ['96', './step2/output_csv/data97.csv'],
#        ['97', './step2/output_csv/data121.csv'],
#        ['98', './step2/output_csv/data69.csv'],
#        ['99', './step2/output_csv/data91.csv'],
#        ['100', './step2/output_csv/data24.csv'],
#        ['101', './step2/output_csv/data71.csv'],
#        ['102', './step2/output_csv/data63.csv'],
#        ['103', './step2/output_csv/data54.csv'],
#        ['104', './step2/output_csv/data146.csv'],
#        ['105', './step2/output_csv/data44.csv'],
#        ['106', './step2/output_csv/data165.csv'],
#        ['107', './step2/output_csv/data184.csv'],
#        ['108', './step2/output_csv/data130.csv'],
#        ['109', './step2/output_csv/data163.csv'],
#        ['110', './step2/output_csv/data47.csv'],
#        ['111', './step2/output_csv/data123.csv'],
#        ['112', './step2/output_csv/data6.csv'],
#        ['113', './step2/output_csv/data164.csv'],
#        ['114', './step2/output_csv/data179.csv'],
#        ['115', './step2/output_csv/data25.csv'],
#        ['116', './step2/output_csv/data57.csv'],
#        ['117', './step2/output_csv/data190.csv'],
#        ['118', './step2/output_csv/data10.csv'],
#        ['119', './step2/output_csv/data52.csv'],
#        ['120', './step2/output_csv/data103.csv'],
#        ['121', './step2/output_csv/data166.csv'],
#        ['122', './step2/output_csv/data81.csv'],
#        ['123', './step2/output_csv/data181.csv'],
#        ['124', './step2/output_csv/data18.csv'],
#        ['125', './step2/output_csv/data70.csv'],
#        ['126', './step2/output_csv/data133.csv'],
#        ['127', './step2/output_csv/data197.csv'],
#        ['128', './step2/output_csv/data16.csv'],
#        ['129', './step2/output_csv/data114.csv'],
#        ['130', './step2/output_csv/data86.csv'],
#        ['131', './step2/output_csv/data187.csv'],
#        ['132', './step2/output_csv/data59.csv'],
#        ['133', './step2/output_csv/data161.csv'],
#        ['134', './step2/output_csv/data182.csv'],
#        ['135', './step2/output_csv/data22.csv'],
#        ['136', './step2/output_csv/data12.csv'],
#        ['137', './step2/output_csv/data193.csv'],
#        ['138', './step2/output_csv/data31.csv'],
#        ['139', './step2/output_csv/data186.csv'],
#        ['140', './step2/output_csv/data39.csv'],
#        ['141', './step2/output_csv/data177.csv'],
#        ['142', './step2/output_csv/data41.csv'],
#        ['143', './step2/output_csv/data73.csv'],
#        ['144', './step2/output_csv/data19.csv'],
#        ['145', './step2/output_csv/data50.csv'],
#        ['146', './step2/output_csv/data122.csv'],
#        ['147', './step2/output_csv/data23.csv'],
#        ['148', './step2/output_csv/data46.csv'],
#        ['149', './step2/output_csv/data142.csv'],
#        ['150', './step2/output_csv/data137.csv'],
#        ['151', './step2/output_csv/data76.csv'],
#        ['152', './step2/output_csv/data194.csv'],
#        ['153', './step2/output_csv/data17.csv'],
#        ['154', './step2/output_csv/data37.csv'],
#        ['155', './step2/output_csv/data168.csv'],
#        ['156', './step2/output_csv/data15.csv'],
#        ['157', './step2/output_csv/data99.csv'],
#        ['158', './step2/output_csv/data92.csv'],
#        ['159', './step2/output_csv/data141.csv']], dtype=object)

# %%
test_file = np.loadtxt('./test_file7_list.csv', delimiter=',',skiprows=1, dtype='object')
train_file = np.loadtxt('./train_file7_list.csv', delimiter=',',skiprows=1, dtype='object')

# apply SVM
for num in range(len(train_file)):
    df = pd.read_csv(train_file[num])
#     df = np.loadtxt(train_file[num], delimiter=',', skiprows=1)
    clf = svm.SVC()
#     train_X,train_y = df[:,:-1],df[:,-1]
    train_X,train_y = df.iloc[:,:-1].values,df.iloc[:,-1].values
    clf.fit(train_X,train_y)
# output model
joblib.dump(clf, './train7.learn')
# load model
clf4 = joblib.load('./train7.learn')
# load test data
savename = join('./','./evaluation7_7.xlsx')
if os.path.exists(savename):
    os.remove(savename)
for num in range(len(test_file)):
#     df = pd.read_csv(train_file[num])
    df = np.loadtxt(test_file[num], delimiter=',', skiprows=1)
    test_X,test_y = df[:,:-1],df[:,-1]
    # result
    predicted_y = clf4.predict(test_X)
    # evaluation
    report = classification_report(test_y, predicted_y, output_dict=True)
    sheetname = os.path.splitext(os.path.basename(test_file[num]))[0]
    result = pd.DataFrame(report).transpose()
    if os.path.exists(savename):
        with pd.ExcelWriter(savename, engine="openpyxl", mode="a") as writer:
            result.to_excel(writer, sheet_name=sheetname)
    else:
        with pd.ExcelWriter(savename, engine="openpyxl") as writer:
            result.to_excel(writer, sheet_name=sheetname)
    

#     score = metrics.accuracy_score(test_y, predicted_y)
#     print("Score:", score)
# Out:
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/jh372/local/python/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# from sklearn.metrics import classification_report
# # output model
# joblib.dump(clf, './train.learn')
# # load model
# clf4 = joblib.load('./train.learn')
# # load test data
# for num in range(len(test_file)):
#     df = pd.read_csv(train_file[num])
#     test_X,test_y = df.iloc[:,:-1].values,df.iloc[:,-1].values
#     predicted_y = clf4.predict(test_X)
#     score = classification_report(test_y, predicted_y)
# #     score = metrics.accuracy_score(test_y, predicted_y)
#     print(score)

# %%
# from sklearn.metrics import classification_report
# # load model
# clf4 = joblib.load('./train.learn')

# %%
# from sklearn.metrics import classification_report
# # # output model
# # joblib.dump(clf, './train.learn')
# # load model
# clf4 = joblib.load('./train.learn')
# tic()
# # load test data
# for num in range(len(test_file)):
#     df = np.loadtxt(test_file[num],delimiter=',',skiprows=1)
#     test_X,test_y = df[:,:-1], df[:,-1]
# #     df = pd.read_csv(train_file[num])
# #     test_X,test_y = df.iloc[:,:-1].values,df.iloc[:,-1].values
#     predicted_y = clf4.predict(test_X)
#     score = classification_report(test_y, predicted_y)
# #     score = metrics.accuracy_score(test_y, predicted_y)
#     print(score)
# toc()

# %%
# # test
# # tic()
# df1 = pd.read_csv(train_file[0]) #elapsed time: 151.782285452 [sec]
# # X1,y1 = df1.iloc[:,:-1].values,df1.iloc[:,-1].values
# data = np.loadtxt(test_file[0],delimiter=',',skiprows=1) #elapsed time: 152.524085045 [sec]
# X, y = data[:,:-1], data[:,-1]
# X
# # pre_y1 = clf4.predict(X)
# # score1 = classification_report(y1, pre_y1)
# # print(score1)
# # toc()

# %%
# for counting time
import time

def tic():
    #require  to import time
    global start_time_tictoc
    start_time_tictoc = time.time()


def toc(tag="elapsed time"):
    if "start_time_tictoc" in globals():
        print("{}: {:.9f} [sec]".format(tag, time.time() - start_time_tictoc))
    else:
        print("tic has not been called")
